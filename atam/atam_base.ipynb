# %%
import os
from pathlib import Path

while not Path("data").exists():
    os.chdir("..")

from atam.pipeline_base import run_base_pipeline

DATA_ROOT = Path("data")
OUTPUT_ROOT = Path("outputs")
PROMPT_PATH = Path("atam") / "prompts" / "base_scenario_mapping.md"

# discover domains automatically
domains = [
    d for d in DATA_ROOT.iterdir()
    if d.is_dir()
    and d.name != "prompts"
    and (d / "scenarios.json").exists()
    and (d / "architectures").exists()
]

print(f"Discovered domains: {[d.name for d in domains]}")

run_dirs = {}

for domain_dir in domains:
    print(f"\n=== Running pipeline for domain: {domain_dir.name} ===")

    run_dir = run_base_pipeline(
        domain_dir=domain_dir,
        out_root=OUTPUT_ROOT,
        prompt_path=PROMPT_PATH,
        # ollama_host="localhost:11434",
        model="anthropic/claude-haiku-4.5",
        provider="openrouter",
        max_retries=2,
    )

    run_dirs[domain_dir.name] = run_dir
    print(f"Completed domain '{domain_dir.name}', output in: {run_dir}")

print("\nAll pipeline runs completed.")
# Out:
# Discovered domains: ['travel-booking-system', 'human-resource-system', 'ecommerce-system', 'secure-rooms-system', 'online-learning-platform-system']
#
# === Running pipeline for domain: travel-booking-system ===
# Completed domain 'travel-booking-system', output in: outputs/travel-booking-system/run-20260303-104237
#
# === Running pipeline for domain: human-resource-system ===
# Completed domain 'human-resource-system', output in: outputs/human-resource-system/run-20260303-104512
#
# === Running pipeline for domain: ecommerce-system ===
# Completed domain 'ecommerce-system', output in: outputs/ecommerce-system/run-20260303-104929
#
# === Running pipeline for domain: secure-rooms-system ===
# Completed domain 'secure-rooms-system', output in: outputs/secure-rooms-system/run-20260303-105934
#
# === Running pipeline for domain: online-learning-platform-system ===
# Completed domain 'online-learning-platform-system', output in: outputs/online-learning-platform-system/run-20260303-110408
#
# All pipeline runs completed.
